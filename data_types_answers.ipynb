# %% [markdown]
# # Python recap 🐍
#
# ## Data types and structures 🅰️ 🆎 🅱️ 🅾️
#
# 1. Numeric Types:
#     - int: Integer
#     - float: Floating Point Number
#     - complex: Complex Number (e.g., 1 + 2j)
# 1. Text Type:
#     - str: String
# 1. Sequence Types:
#     - list: List
#     - tuple: Tuple
#     - range: Range
#     - Mapping Type:
#     - dict: Dictionary
# 1. Set Types:
#     - set: Set
#     - frozenset: Frozenset (immutable version of set)
# 1. Boolean Type:
#     - bool: Boolean (True or False)
# 1. Binary Types:
#     - handle raw data in the form of bytes and byte arrays
# 1. None Type:
#     - Represents the absence of a value or a null value. There's only one instance of this data type, the None value.
# 1. Function and Modules:
#     - Although not often referred to as data types in a traditional sense, functions (function) and modules (module) are types in Python and can be queried using the type() function

# %% [markdown]
# ## 2. Rules for variable names
#
# - names can not start with a number
# - names can not contain spaces, use _ intead
# - names can not contain any of these symbols:
#     :'",<>/?|\!@#%^&*~-+
# - it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)) that names are lowercase with underscores
# - you must not use Python built-in keywords like `list` and `str`
# - avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with `1` and `0`

# %% [markdown]
# ### Integers (int): Whole numbers, positive or negative

# %%
my_int = 5
type(my_int)
# Out:
# int

# %%
help(my_int)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %% [markdown]
# ## 🏋️🏋️ **In pairs** or individually 🏋️
#
# - with or without Google use any of the empty cells below to illustrate any of the data types from the list above.

# %% [markdown]
# ### Floating Point (float): Numbers with a decimal point.

# %%
my_float = 5.3
type(my_float)
# help(my_float)
# Out:
# Help on float object:
#
# class float(object)
#  |  float(x=0, /)
#  |
#  |  Convert a string or number to a floating point number, if possible.
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __bool__(self, /)
#  |      True if self else False
#  |
#  |  __ceil__(self, /)
#  |      Return the ceiling as an Integral.
#  |
#  |  __divmod__(self, value, /)
#  |      Return divmod(self, value).
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __float__(self, /)
#  |      float(self)
#  |
#  |  __floor__(self, /)
#  |      Return the floor as an Integral.
#  |
#  |  __floordiv__(self, value, /)
#  |      Return self//value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Formats the float according to format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
# ...

# %%
my_a = 0.1
my_b = 0.2
my_result = my_a + my_b

expected_result = 0.3

# Check if the result is what we expect
is_equal = my_result == expected_result

my_result, is_equal
# Out:
# (0.30000000000000004, False)

# %% [markdown]
# ### Type casting int/float

# %%
# Casting an into a float
my_integer = 3
my_integer+=0.1
type(my_integer)
# Out:
# float

# %%
# Casting a float to an int
float_number = 7.8
casted_to_int = int(float_number)
casted_to_int, type(casted_to_int)
# Out:
# (7, int)

# %%
# Casting a string that looks like a float to an int directly causes a ValueError
str_number = "7.8"
try:
    casted_str_to_int = int(str_number)
except ValueError as e:
    error_message = str(e)
    
type(str_number), error_message
# Out:
# (str, "invalid literal for int() with base 10: '7.8'")

# %% [markdown]
# ### Strings (str): Sequences of characters, enclosed in single or double quotes.

# %%
my_string = "Hello, World!"
type(my_string)
# Out:
# str

# %%
# Strings are sequences, so we can do sequence operations:
palindrome = "racecar"
is_palindrome = palindrome == palindrome[::-1]
palindrome[::-1]
# Out:
# 'racecar'

# %%
# Multiplying strings:
cheer = "Hip " * 3 + "Hooray!"
cheer
# Out:
# 'Hip Hip Hip Hooray!'

# %%
# Fun with String Slicing

sentence = "Python is fun!"

# Basic slicing
first_five_chars = sentence[:5]

# Slicing with negative indices
last_five_chars = sentence[-5:]

# Slicing with steps
alternate_chars = sentence[::2]
reverse_string = sentence[::-1]

# Slicing beyond the string's length doesn't raise an error
beyond_length = sentence[5:100]

# A slice of a string can be used to form a new word
word_play = sentence[7:10] + sentence[1:3]

# Let's see the sliced and diced results!
first_five_chars, last_five_chars, alternate_chars, reverse_string, beyond_length, word_play
# Out:
# ('Pytho', ' fun!', 'Pto sfn', '!nuf si nohtyP', 'n is fun!', 'is yt')

# %% [markdown]
# ### Lists: Ordered collections of items, which can be of any type. Lists are mutable.
#
# Python lists are heterogeneous, meaning they can contain elements of different data types. Numpy array is not.

# %%
my_list = [1, 2, 3, "apple", 5.6]
type(my_list)
# Out:
# list

# %%
import random

# Magician's Hat 🎩
magicians_hat = ["🐇", "🐥", "♣️", "🥀", "💰", "🌺", "📦"]

# Magically reveal a random thing from the hat 🪄
random_reveal = random.choice(magicians_hat)

# Removing the revealed item from the hat (because magic items vanish once revealed!)
magicians_hat.remove(random_reveal)

f"The magician magically reveals a... {random_reveal}!", f"Remaining items in the hat: {magicians_hat}"
# Out:
# ('The magician magically reveals a... 🥀!',
#  "Remaining items in the hat: ['🐇', '🐥', '♣️', '💰', '🌺', '📦']")

# %%
# Fake lists of numbers
x_values = [5, 12, 23, 34, 45, 56, 67, 78, 89, 92]
y_values = [12, 25, 30, 45, 58, 60, 71, 85, 90, 95]

# If you want to plot these values, you can use the following:

import matplotlib.pyplot as plt

plt.figure(figsize=(12, 7))
plt.scatter(x_values, y_values, color='red', marker='o')
plt.title('Scatter Plot of Fake Data')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ### Tuples: Ordered collections like lists, but immutable.

# %%
# Fun with Tuples

# Creating a basic tuple
animals = ("cat", "dog", "elephant")

# Unlike lists, tuples are immutable. Let's see what happens when we try to change one.
try:
    animals[1] = "dolphin"
except TypeError as e:
    error_message = str(e)

animals, error_message
# Out:
# (('cat', 'dog', 'elephant'), "'tuple' object does not support item assignment")

# %%
# Tuples can be concatenated
more_animals = animals + ("fish", "giraffe")

# Nesting tuples
zoo = (animals, ("lion", "zebra", "kangaroo"))

zoo
# Out:
# (('cat', 'dog', 'elephant'), ('lion', 'zebra', 'kangaroo'))

# %%
# Tuple unpacking!
cat, dog, elephant = animals
unpacked_animals = f"Unpacked: {cat}, {dog}, and {elephant}"

unpacked_animals
# Out:
# 'Unpacked: cat, dog, and elephant'

# %%
# Fun with Tuple Slicing

# A journey through time and space with Doctor Who's TARDIS
tardis_journey = ("1963", "Medieval England", "Victorian London", "Mars", "End of Time", "Gallifrey")

# Let's take a short trip to the first three destinations
short_trip = tardis_journey[:3]

short_trip
# Out:
# ('1963', 'Medieval England', 'Victorian London')

# %%
# Oops! The TARDIS overshot. We're now somewhere at the end of the universe!
end_of_universe = tardis_journey[-2:]

end_of_universe
# Out:
# ('End of Time', 'Gallifrey')

# %%
# Timey-wimey stuff! Let's jump through every alternate location
alternate_jumps = tardis_journey[::2]
alternate_jumps
# Out:
# ('1963', 'Victorian London', 'End of Time')

# %%
# Let's take a detour and reverse our journey
reverse_journey = tardis_journey[::-1]
reverse_journey
# Out:
# ('Gallifrey',
#  'End of Time',
#  'Mars',
#  'Victorian London',
#  'Medieval England',
#  '1963')

# %%
# A slice from another dimension (slicing beyond the tuple's length doesn't cause an error)
beyond_time = tardis_journey[4:100]
beyond_time
# Out:
# ('End of Time', 'Gallifrey')

# %% [markdown]
# ### Dictionaries (dict): Unordered collections of key-value pairs.

# %%
# Basic dictionary
favorite_fruits = {
    "Alice": "Apple",
    "Bob": "Banana",
    "Charlie": "Cherry"
}

# Accessing a key that doesn't exist... oops!
try:
    daves_fruit = favorite_fruits["Dave"]
except KeyError as e:
    error_message = f"KeyError: {str(e)}"

# Using the `get` method to provide a default value for missing keys
daves_fruit = favorite_fruits.get("Dave", "Unknown fruit")

# Dictionary comprehensions! Let's reverse our dictionary
reversed_fruits = {value: key for key, value in favorite_fruits.items()}

error_message, daves_fruit, reversed_fruits
# Out:
# ("KeyError: 'Dave'",
#  'Unknown fruit',
#  {'Apple': 'Alice', 'Banana': 'Bob', 'Cherry': 'Charlie'})

# %%
# Modifying the favorite_fruits dictionary
favorite_fruits["Dave"] = "Dragonfruit"

favorite_fruits
# Out:
# {'Alice': 'Apple', 'Bob': 'Banana', 'Charlie': 'Cherry', 'Dave': 'Dragonfruit'}

# %%
# Keys and values
fruit_keys = list(favorite_fruits.keys())
fruit_values = list(favorite_fruits.values())

fruit_keys, fruit_values
# Out:
# (['Alice', 'Bob', 'Charlie', 'Dave'],
#  ['Apple', 'Banana', 'Cherry', 'Dragonfruit'])

# %%
sales_data = {
    "Apples": 50,
    "Bananas": 35,
    "Cherries": 20,
    "Dates": 10
}

# %%
import matplotlib.pyplot as plt

# Example data
data = {
    "Apples": 50,
    "Bananas": 35,
    "Cherries": 20,
    "Dates": 10
}

# Create the bar chart
plt.figure(figsize=(10, 6))
plt.bar(data.keys(), data.values(), color=['red', 'yellow', 'pink', 'brown'])
plt.title('Fruit Quantities')
plt.xlabel('Fruit')
plt.ylabel('Quantity')
plt.show()

# %%
sales_data = {
    "Monday": 150,
    "Tuesday": 180,
    "Wednesday": 210,
    "Thursday": 170,
    "Friday": 220,
    "Saturday": 230,
    "Sunday": 190
}

# %%
# Create the line graph for weekly sales
plt.figure(figsize=(12, 7))
plt.plot(list(sales_data.keys()), list(sales_data.values()), marker='o', color='green', linestyle='-', linewidth=2)
plt.title('Weekly Sales Trend')
plt.xlabel('Day of the Week')
plt.ylabel('Sales')
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
plt.show()

# %% [markdown]
# ### Sets: Unordered collections of unique values.
#
# Note: To create an empty set in Python, you need to use set(). Using {} would create an empty dictionary, not a set.
#
# Sets in mathematics refer to a collection of distinct (unique) objects, considered as an entity itself. Set theory is the branch of mathematical logic that studies sets, their operations, and the properties and relations of these operations.
#
# $ S_1 = \{1, 2, 3, 4, 5\} $
# $ S_2 = \{\text{apple}, \text{banana}, \text{cherry}\} $
#
# An xample of Maths sets operations is union:
#
# $ S_1 \cup S_2  = \{1, 2, 3, 4, 5, \text{apple}, \text{banana}, \text{cherry}\} $

# %%
# Using curly braces
fruits = {"apple", "banana", "cherry"}

# Using the set() constructor
vegetables = set(["broccoli", "carrot", "spinach"])

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

union_set = A | B

union_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
intersection_set = A & B
intersection_set
# Out:
# {3, 4}

# %%
difference_set = A - B
difference_set
# Out:
# {1, 2}

# %%
# using a set to remove duplicates from a list

original_list = [1, 2, 2, 3, 4, 4, 5, 5, 5]
deduplicated_list = list(set(original_list))
deduplicated_list
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Booleans (bool): Logical values indicating True or False.

# %%
h = True
i = False
type(h), type(i)
# Out:
# (bool, bool)

# %% [markdown]
# ### The `None` Type
#
# The `None` Type in Python represents the absence of a value or a null value. The only value of this type is the None value. It's often used to signify the absence of a value in functions, default arguments, and data structures, among other places.

# %%
# Different ways you might encounter None

# A function that doesn't return anything, actually returns None
def do_nothing():
    pass

result = do_nothing()

# Variables can be assigned the value of None
empty_variable = None

# Dictionary values or list elements can be None
sample_dict = {"key": None}
sample_list = [None, 1, 2]

# Check type
none_type = type(None)

result, empty_variable, sample_dict, sample_list, none_type
# Out:
# (None, None, {'key': None}, [None, 1, 2], NoneType)

# %% [markdown]
# ### Functions
#
# In Python, a function is a block of organized, reusable code that performs a single, related action. Functions provide better modularity for your application and allow for a high degree of code reusing. Python functions usually have:
#
# - parameters: (Optional) Values you can pass into the function.
# - docstring: (Optional) A brief description of what the function does.
# - return: (Optional) This keyword is used to send a result back to the caller.

# %%
# function definition

def function_name(parameters):
    """docstring"""
    # function body
    return value

# %%
# function definition

def greet(name):
    """This function greets the person passed in as a parameter."""
    return f"Hello, {name}!"

# %%
# function call

message = greet('Alice')
print(message)  # Output: Hello, Alice!

# %%
#dictionary

architect_buildings = {
    "Richard Rogers": "Cheesegrater 🧀",
    "Norman Foster": "Gherkin 🥒",
    "Christpher Wren": "Wedding Cake 🎂",
    "SOM": "Scalpel 🔪"
}


for architect in architect_buildings:
    building = architect_buildings[architect]
    print(f"Name the architect of this building: {building}!")
    answer = input("Architect name: ")
    print(answer in architect_buildings)
# Out:
# Name the architect of this building: Cheesegrater 🧀!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [6], line 12
#      10 building = architect_buildings[architect]
#      11 print(f"Name the architect of this building: {building}!")
# ---> 12 answer = input("Architect name: ")
#      13 print(answer in architect_buildings)
#
# File /shared-libs/python3.9/py-core/lib/python3.9/site-packages/ipykernel/kernelbase.py:1177, in Kernel.raw_input(self, prompt)
#    1173 if not self._allow_stdin:
#    1174     raise StdinNotImplementedError(
#    1175         "raw_input was called, but this frontend does not support input requests."
#    1176     )
# -> 1177 return self._input_request(
#    1178     str(prompt),
#    1179     self._parent_ident["shell"],
#    1180     self.get_parent("shell"),
#    1181     password=False,
#    1182 )
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1a321bf6-d808-4a88-8d69-b5f5b47ac9ef' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
