# %%
def fun_function(input_string):
    # Reverse the string
    reversed_str = input_string[::-1]
    
    # Count the vowels
    vowels = 'aeiouAEIOU'
    vowel_count = sum(1 for char in input_string if char in vowels)
    
    return reversed_str, vowel_count

# %%
result = fun_function("Hello, World!")
print(result)
# Out:
# ('!dlroW ,olleH', 3)

# %%
def greet(name):
    print(f"Hello, {name}!")

# %%
greet("Walter")
# Out:
# Hello, Walter!

# %%
result = greet("Walter")  # This prints what function says
print(result)  # This prints "None"
# Out:
# Hello, Walter!
# None

# %%
type(None), type(result)
# Out:
# (NoneType, NoneType)

# %%
def extract_keys(my_dictionary):
    return list(my_dictionary.keys())

# %%
data = {
    "apple": 5,
    "banana": 3,
    "cherry": 7
}

extract_keys(data)
# Out:
# ['apple', 'banana', 'cherry']

# %%
def can_enter_club(age, has_formal_attire, is_vip):
    return (age >= 21 and has_formal_attire) or is_vip

# %%
can_enter_club(18, False, False)
# Out:
# False

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1a321bf6-d808-4a88-8d69-b5f5b47ac9ef' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
