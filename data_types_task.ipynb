# %% [markdown]
# # Python recap 🐍
#
# ## Data types and structures 🅰️ 🆎 🅱️ 🅾️
#
# 1. Numeric Types:
#     - int: Integer
#     - float: Floating Point Number
#     - complex: Complex Number (e.g., 1 + 2j)
# 1. Text Type:
#     - str: String
# 1. Sequence Types:
#     - list: List
#     - tuple: Tuple
#     - range: Range
#     - Mapping Type:
#     - dict: Dictionary
# 1. Set Types:
#     - set: Set
#     - frozenset: Frozenset (immutable version of set)
# 1. Boolean Type:
#     - bool: Boolean (True or False)
# 1. Binary Types:
#     - handle raw data in the form of bytes and byte arrays
# 1. None Type:
#     - Represents the absence of a value or a null value. There's only one instance of this data type, the None value.
# 1. Function and Modules:
#     - Although not often referred to as data types in a traditional sense, functions (function) and modules (module) are types in Python and can be queried using the type() function

# %% [markdown]
# ## 2. Rules for variable names
#
# - names can not start with a number
# - names can not contain spaces, use _ intead
# - names can not contain any of these symbols:
#     :'",<>/?|\!@#%^&*~-+
# - it's considered best practice ([PEP8](https://www.python.org/dev/peps/pep-0008/#function-and-variable-names)) that names are lowercase with underscores
# - you must not use Python built-in keywords like `list` and `str`
# - avoid using the single characters `l` (lowercase letter el), `O` (uppercase letter oh) and `I` (uppercase letter eye) as they can be confused with `1` and `0`

# %% [markdown]
# ### Integers (int): Whole numbers, positive or negative

# %%
my_int = 5
type(my_int)
# Out:
# int

# %%
# help(my_int)
# Out:
# Help on int object:
#
# class int(object)
#  |  int([x]) -> integer
#  |  int(x, base=10) -> integer
#  |
#  |  Convert a number or string to an integer, or return 0 if no arguments
#  |  are given.  If x is a number, return x.__int__().  For floating point
#  |  numbers, this truncates towards zero.
#  |
#  |  If x is not a number or if base is given, then x must be a string,
#  |  bytes, or bytearray instance representing an integer literal in the
#  |  given base.  The literal can be preceded by '+' or '-' and be surrounded
#  |  by whitespace.  The base defaults to 10.  Valid bases are 0 and 2-36.
#  |  Base 0 means to interpret the base from the string as an integer literal.
#  |  >>> int('0b100', base=0)
#  |  4
#  |
#  |  Built-in subclasses:
#  |      bool
#  |
#  |  Methods defined here:
#  |
#  |  __abs__(self, /)
#  |      abs(self)
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __and__(self, value, /)
#  |      Return self&value.
#  |
# ...

# %% [markdown]
# ## 🏋️🏋️ **In pairs** or individually 🏋️
#
# I recommend driver-navigator pair programming. **Pair programming** is a software development/data science technique in which two programmers work together at one workstation. One, **the driver**, writes code while the other, the **navigator**, reviews each line of code as it is typed in and givees directions (what to type). The two programmers can switch roles.
#
# - with or without Google use any of the empty cells below to illustrate any of the data types from the list above.
# - call `.type()` and `.help()` and possiblye `.dir()` on the variables you created
# - think of some fun examples to use: charts, jokes etc
# - my answers are in the answers notebook

# %%
# cell 1

# %%
# cell 2

# %%
# cell 3

# %%
# cell 4

# %%
# cell 5

# %%
# cell 6

# %%
# cell 7

# %%
# cell 8

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=1a321bf6-d808-4a88-8d69-b5f5b47ac9ef' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
